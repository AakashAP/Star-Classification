# %%
1. Data Loading
2. Data Preprocessing.
3. Data Manipulation
4. Feature Selection
5. Data Splitting
6. Standardization
7. Normalization
8. Model Building
9. Model Evaluation
10. Testing Evaluation
